# %%
import gym
import torch 
import collections
import os
import numpy as np
from utils import *
from exp_replay_memory import ReplayMemory

# %%
width=0.2

# %% [markdown]
# # SARSA

# %%
def epsilon_greedy(q_func, observation, eps, env_actions):
    prob = np.random.random()

    if prob < eps:
        return random.choice(range(env_actions))
    elif isinstance(q_func, CNN) or isinstance(q_func, LinearMapNet):
        with torch.no_grad():
            return q_func(observation).max(1)[1].item()
    else:
        qvals = [q_func[observation + (action, )] for action in range(env_actions)]
        return np.argmax(qvals)
    
def greedy(qstates_dict, observation, env_actions):
    qvals = [qstates_dict[observation + (action, )] for action in range(env_actions)]
    return max(qvals)

# %%
def sarsa_lander(env, n_episodes, gamma, lr, min_eps,width, print_freq=500, render_freq=500):
    q_observations = collections.defaultdict(float)   # note that the first insertion of a key initializes its value to 0.0
    return_per_ep = [0.0]
    epsilon = 1.0
    num_actions = env.action_space.n
    
    for i in range(n_episodes):
        t = 0

        # Initial episode state: S
        curr_state = discretize_state(env.reset())
        if curr_state[1]>=1-width/2 and curr_state[1]<=1+width/2:
            if curr_state[0]<0: # send different information for left, middle and right
                curr_observation = (-1,)
            elif curr_state[0]==0:
                curr_observation = (0,)
            else:
                curr_observation = (1,)
        else:
            curr_observation = curr_state
                 
        # Choose A from S using policy π
        action = epsilon_greedy(q_observations, curr_observation, epsilon, num_actions)
        
        while True:

            # Create (S, A) pair
            qstate = curr_state + (action, )
            qobservation = curr_observation + (action, )

            # Take action A, earn immediate reward R and land into next state S'
            # S --> A --> R --> S'
            state_continuous, reward, done, _ = env.step(action)
            next_state = discretize_state(state_continuous)
            if next_state[1]>=1-width/2 and next_state[1]<=1+width/2:
                if next_state[0]<0: # send different information for left, middle and right
                    next_observation = (-1,)
                elif next_state[0]==0:
                    next_observation = (0,)
                else:
                    next_observation = (1,)
            else:
                next_observation = next_state

            # Next State: S'
            # Choose A' from S' using policy π
            next_action = epsilon_greedy(q_observations, next_observation, epsilon, num_actions)

            # create (S', A') pair
            new_qstate = next_state + (next_action, )
            new_qobservation = next_observation + (next_action, )

            ###################################################################
            # Policy evaluation step
            if not done:
                q_observations[qobservation] += lr * (reward + gamma * q_observations[new_qobservation] - q_observations[qobservation]) # (S', A') non terminal state
            else:
                q_observations[qobservation] += lr * (reward - q_observations[qobservation])    # (S', A') terminal state
            ###################################################################

            return_per_ep[-1] += reward

            if done:
                if (i + 1) % print_freq == 0:
                    print("\nEpisode finished after {} timesteps".format(t + 1))
                    print("Episode {}: Total Return = {}".format(i + 1, return_per_ep[-1]))
                    print("Total keys in q_observations dictionary = {}".format(len(q_observations)))

                if (i + 1) % 100 == 0:
                    mean_100ep_reward = round(np.mean(return_per_ep[-101:-1]), 1)
                    print("Last 100 episodes mean reward: {}".format(mean_100ep_reward))

                epsilon = decay_epsilon(epsilon, min_eps)
                return_per_ep.append(0.0)

                break

            curr_state = next_state
            curr_observation = next_observation
            action = next_action
            t += 1

    return return_per_ep

# %%
n_episodes=10000
lr=0.1
gamma=0.99
final_eps=0.01
environment = gym.make("LunarLander-v2")

# %%
print("\nTraining Sarsa lander with arguments num_episodes={}, step-size={}, gamma={}, final_epsilon={} ..."\
                            .format(n_episodes, lr, gamma, final_eps))
sarsa_total_rewards  = sarsa_lander(environment, n_episodes, gamma, lr, final_eps,width)
print("Done!")
environment = gym.make("LunarLander-v2")
# Out:
# Training Sarsa lander with arguments num_episodes=10000, step-size=0.1, gamma=0.99, final_epsilon=0.01 ...
# Last 100 episodes mean reward: -148.6
# Last 100 episodes mean reward: -105.1
# Last 100 episodes mean reward: -80.9
# Last 100 episodes mean reward: -135.1
#
# Episode finished after 150 timesteps
# Episode 500: Total Return = -212.19116668379192
# Total keys in q_observations dictionary = 8139
# Last 100 episodes mean reward: -148.0
# Last 100 episodes mean reward: -126.3
# Last 100 episodes mean reward: -134.1
# Last 100 episodes mean reward: -141.0
# Last 100 episodes mean reward: -133.2
#
# Episode finished after 177 timesteps
# Episode 1000: Total Return = -110.45485312962992
# Total keys in q_observations dictionary = 11921
# Last 100 episodes mean reward: -117.4
# Last 100 episodes mean reward: -127.5
# Last 100 episodes mean reward: -99.8
# Last 100 episodes mean reward: -110.6
# Last 100 episodes mean reward: -101.1
#
# Episode finished after 130 timesteps
# Episode 1500: Total Return = -85.6031840487449
# Total keys in q_observations dictionary = 15537
# Last 100 episodes mean reward: -66.2
# Last 100 episodes mean reward: -53.3
# Last 100 episodes mean reward: -67.4
# Last 100 episodes mean reward: -68.6
# Last 100 episodes mean reward: -58.5
#
# Episode finished after 602 timesteps
# Episode 2000: Total Return = -94.15264648926083
# Total keys in q_observations dictionary = 19432
# Last 100 episodes mean reward: -49.2
# Last 100 episodes mean reward: -61.5
# Last 100 episodes mean reward: -100.2
# Last 100 episodes mean reward: -77.5
# Last 100 episodes mean reward: -90.0
#
# Episode finished after 617 timesteps
# Episode 2500: Total Return = -5.509229394575897
# Total keys in q_observations dictionary = 22151
# Last 100 episodes mean reward: -52.1
# Last 100 episodes mean reward: -53.6
# Last 100 episodes mean reward: -16.7
# Last 100 episodes mean reward: 30.7
# Last 100 episodes mean reward: 48.8
#
# Episode finished after 633 timesteps
# Episode 3000: Total Return = -99.50119162232923
# Total keys in q_observations dictionary = 23858
# Last 100 episodes mean reward: -1.5
# Last 100 episodes mean reward: -0.9
# Last 100 episodes mean reward: 27.0
# Last 100 episodes mean reward: -35.0
# Last 100 episodes mean reward: 45.5
#
# Episode finished after 855 timesteps
# Episode 3500: Total Return = 173.1358514273543
# Total keys in q_observations dictionary = 24742
# Last 100 episodes mean reward: 41.0
# Last 100 episodes mean reward: 18.1
# Last 100 episodes mean reward: 59.5
# Last 100 episodes mean reward: 25.2
# Last 100 episodes mean reward: 18.8
#
# Episode finished after 166 timesteps
# Episode 4000: Total Return = -49.60186850635294
# Total keys in q_observations dictionary = 25688
# Last 100 episodes mean reward: 16.5
# Last 100 episodes mean reward: -50.6
# Last 100 episodes mean reward: 29.1
# Last 100 episodes mean reward: 5.9
# Last 100 episodes mean reward: 41.5
#
# Episode finished after 748 timesteps
# Episode 4500: Total Return = 156.02042074216558
# Total keys in q_observations dictionary = 26738
# Last 100 episodes mean reward: -44.9
# Last 100 episodes mean reward: 54.4
# Last 100 episodes mean reward: -10.6
# Last 100 episodes mean reward: -5.6
# Last 100 episodes mean reward: -20.7
#
# Episode finished after 484 timesteps
# Episode 5000: Total Return = -61.223072281864916
# Total keys in q_observations dictionary = 27765
# Last 100 episodes mean reward: -47.3
# Last 100 episodes mean reward: 33.6
# Last 100 episodes mean reward: 27.5
# Last 100 episodes mean reward: -41.0
# Last 100 episodes mean reward: 41.2
#
# Episode finished after 547 timesteps
# Episode 5500: Total Return = 248.74102462085145
# Total keys in q_observations dictionary = 28724
# Last 100 episodes mean reward: 69.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ad8ca2d50cf2> in <module>
#       1 print("\nTraining Sarsa lander with arguments num_episodes={}, step-size={}, gamma={}, final_epsilon={} ..."\
#       2                             .format(n_episodes, lr, gamma, final_eps))
# ----> 3 sarsa_total_rewards  = sarsa_lander(environment, n_episodes, gamma, lr, final_eps,width)
#       4 print("Done!")
#       5 environment = gym.make("LunarLander-v2")
#
# <ipython-input-10-9239290bc66f> in sarsa_lander(env, n_episodes, gamma, lr, min_eps, width, print_freq, render_freq)
#      45             # Next State: S'
#      46             # Choose A' from S' using policy π
# ---> 47             next_action = epsilon_greedy(q_observations, next_observation, epsilon, num_actions)
#      48
#      49             # create (S', A') pair
#
# <ipython-input-3-e6423017bdfa> in epsilon_greedy(q_func, observation, eps, env_actions)
#       9     else:
#      10         qvals = [q_func[observation + (action, )] for action in range(env_actions)]
# ---> 11         return np.argmax(qvals)
#      12
#      13 def greedy(qstates_dict, observation, env_actions):
#
# <__array_function__ internals> in argmax(*args, **kwargs)
#
# E:\anaconda\lib\site-packages\numpy\core\fromnumeric.py in argmax(a, axis, out)
#    1186
#    1187     """
# -> 1188     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1189
#    1190
#
# E:\anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      53     bound = getattr(obj, method, None)
#      54     if bound is None:
# ---> 55         return _wrapit(obj, method, *args, **kwds)
#      56
#      57     try:
#
# E:\anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      42     except AttributeError:
#      43         wrap = None
# ---> 44     result = getattr(asarray(obj), method)(*args, **kwds)
#      45     if wrap:
#      46         if not isinstance(result, mu.ndarray):
#
# KeyboardInterrupt:

# %%
# #save result
a=np.array(sarsa_total_rewards)
np.save(f'sarsa_total_rewards_partial_information_width={width}.npy',a)

# %% [markdown]
# # DQN

# %%
def dqn_lander(env, n_episodes, gamma, lr, min_eps, width, \
                batch_size=32, memory_capacity=50000, \
                network='linear', learning_starts=1000, \
                train_freq=1, target_network_update_freq=1000, \
                print_freq=500, render_freq=500, save_freq=1000):

    # set device to run on
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    loss_function = torch.nn.MSELoss()

    # path to save checkpoints
    PATH = "./models"
    if not os.path.isdir(PATH):
        os.mkdir(PATH)

    num_actions = env.action_space.n
    
    input_shape = env.observation_space.shape[-1]
    
    qnet, qnet_optim = build_qnetwork(num_actions, lr, input_shape, network, device)
    qtarget_net, _ = build_qnetwork(num_actions, lr, input_shape, network, device)
    qtarget_net.load_state_dict(qnet.state_dict())
    qnet.train()
    qtarget_net.eval()
    replay_memory = ReplayMemory(memory_capacity)

    epsilon = 1.0 
    return_per_ep = [0.0] 
    saved_mean_reward = None
    t = 0

    for i in range(n_episodes):
        curr_state = lmn_input(env.reset())
       
        # hard coding message for left, middle and right 
        if curr_state[0][1]>=1-width/2 and curr_state[0][1]<=1+width/2: # in the blind area
            if curr_state[0][1] < 0: 
                curr_observation = torch.tensor([[-3.,-3.,-3.,-3.,-3.,-3.,-3.,-3.]])   
            elif curr_state[0][1] == 0:
                curr_observation = torch.tensor([[0.,-3.,-3.,-3.,-3.,-3.,-3.,-3.]])  
            else:
                curr_observation = torch.tensor([[3.,-3.,-3.,-3.,-3.,-3.,-3.,-3.]])  
        else:
            curr_observation = curr_state
                
        if (i + 1) % render_freq == 0:
            render = True
        else:
            render = False

        while True:

            # choose action A using behaviour policy -> ε-greedy; use q-network
            action = epsilon_greedy(qnet, curr_observation.to(device), epsilon, num_actions)
            
            # take action A, earn immediate reward R and land into next state S'
            next_state, reward, done, _ = env.step(action)
            next_state = lmn_input(next_state)
            # hard coding message for left, middle and right 
            if next_state[0][1]>=1-width/2 and next_state[0][1]<=1+width/2: # in the blind area
                if next_state[0][1] < 0: 
                    next_observation = torch.tensor([[-3.,-3.,-3.,-3.,-3.,-3.,-3.,-3.]])   
                elif next_state[0][1] == 0:
                    next_observation = torch.tensor([[0.,-3.,-3.,-3.,-3.,-3.,-3.,-3.]])  
                else:
                    next_observation = torch.tensor([[3.,-3.,-3.,-3.,-3.,-3.,-3.,-3.]])  
            else:
                next_observation =next_state
            

            # store transition (S, A, R, S', Done) in replay memory
            replay_memory.store(curr_observation, action, float(reward), next_observation, float(done))
            
            # if replay memory currently stores > 'learning_starts' transitions,
            # sample a random mini-batch and update q_network's parameters
            if t > learning_starts and t % train_freq == 0:
                curr_observations, actions, rewards, next_observations, dones = replay_memory.sample_minibatch(batch_size)
                #loss = 
                fit(qnet, \
                    qnet_optim, \
                    qtarget_net, \
                    loss_function, \
                    curr_observations, \
                    actions, \
                    rewards, \
                    next_observations, \
                    dones, \
                    gamma, \
                    num_actions, 
                    device)

            # periodically update q-target network's parameters
            if t > learning_starts and t % target_network_update_freq == 0:
                update_target_network(qnet, qtarget_net)

            t += 1
            return_per_ep[-1] += reward

            if done:
                if (i + 1) % print_freq == 0:
                    print("\nEpisode: {}".format(i + 1))
                    print("Episode return : {}".format(return_per_ep[-1]))
                    print("Total time-steps: {}".format(t))

                if (i + 1) % 100 == 0:
                    mean_100ep_reward = round(np.mean(return_per_ep[-101:-1]), 1)
                    print("\nLast 100 episodes mean reward: {}".format(mean_100ep_reward))

                if t > learning_starts and (i + 1) % save_freq == 0:
                    if saved_mean_reward is None or mean_100ep_reward > saved_mean_reward:
                        print("\nSaving model due to mean reward increase: {} -> {}".format(saved_mean_reward, mean_100ep_reward))
                        save_model(qnet, i + 1, PATH)
                        saved_mean_reward = mean_100ep_reward

                return_per_ep.append(0.0)
                epsilon = decay_epsilon(epsilon, min_eps)

                break
            current_state = next_state
            curr_observation = next_observation

    return return_per_ep

# %%
n_episodes= 10000
lr = 0.001
gamma = 0.99
final_eps = 0.01

environment = gym.make("LunarLander-v2")

# %%
print("\nTraining DQN lander with arguments num_episodes={}, learning rate={}, gamma={}, final_epsilon={} ..."\
                            .format(n_episodes,lr, gamma, final_eps))
dqn_total_rewards = dqn_lander(environment, n_episodes, gamma, lr, final_eps,width)
print("Done!")

# %%
#save result
a=np.array(dqn_total_rewards)
np.save(f'dqn_total_rewards_partial_information_width={width}.npy',a)

# %% [markdown]
# # Plot

# %%
def plot_rewards(chosen_agents, agents_returns, num_episodes, window,width):
    num_intervals = int(num_episodes / window)
    for agent, agent_total_returns in zip(chosen_agents, agents_returns):
        print("{} lander average reward = {} when blind area width ={}".format(agent, sum(agent_total_returns) / num_episodes, width))
        l = []
        for j in range(num_intervals):
            l.append(round(np.mean(agent_total_returns[j * 100 : (j + 1) * 100]), 1))
        plt.plot(range(0, num_episodes, window), l)
        
    plt.xlabel("Episodes")
    plt.ylabel("Average reward per {} episodes".format(window))
    plt.title(f"RL Lander(s), width={width}")
    plt.legend(chosen_agents, loc="lower right")
    plt.show()

# %%
chosen_agents = ['SARSA','DQN']
agents_returns = [sarsa_total_rewards,dqn_total_rewards]

win = 100
plot_rewards(chosen_agents, agents_returns, n_episodes, win,width)
